# %% [markdown]
# ## Running perceptron on data

# %%
from Machine_learning_course.polynomial_features_functions import *
from Machine_learning_course.plot_functions import *
from Machine_learning_course.perceptron_functions import *
from Machine_learning_course.example_datasets import *
# Out:
# <function make_polynomial_feature_fun.<locals>.f at 0x0000022D5A9E4820>

# %%
ax = tidy_plot(-5, 5, -5, 5, center = False, title = None,
                 xlabel = None, ylabel = None)
th = np.array([[1],[2]])
th_0 = 1
plot_separator(ax, th, th_0)

# %%
data = np.array([[1,3],[2,4]])
labels = np.array([1,-1])
plot_data(data, labels, ax = None, clear = False,
                  xmin = None, xmax = None, ymin = None, ymax = None)
# Out:
# <Axes: >

# %%
#(1) super_simple_separable_through_origin, (2) super_simple_separable, (3) xor, and (4) xor_more.
# Enter a Python list of integers indicating the smallest polynomial order for which a separator exists for each of the four datasets in the code file (in order)

test_with_features(super_simple_separable_through_origin, order = 1, draw=True, pause=False)
# Out:
# th [[1. 2. 5.]] th0 [[1.]]
# th [[ 0. -1.  4.]] th0 [[0.]]
# th [[ -1. -13.  -1.]] th0 [[-1.]]
# th [[  0. -11.   4.]] th0 [[0.]]
# th [[ 1. -2. 10.]] th0 [[1.]]
# th [[  0. -14.   5.]] th0 [[0.]]
# th [[  1. -12.  10.]] th0 [[1.]]
# th [[ 2. -3. 16.]] th0 [[2.]]
# th [[  1. -15.  11.]] th0 [[1.]]
# th [[ 2. -6. 17.]] th0 [[2.]]
# th [[  1. -18.  12.]] th0 [[1.]]
# th [[ 2. -9. 18.]] th0 [[2.]]
# th [[ 2. -9. 18.]] th0 [[2.]]
# Final score 4
# Params [[ 2. -9. 18.]] [[2.]]
